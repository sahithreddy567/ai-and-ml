# %% [markdown]
# # CSE-221710308025-K.SAHITH REDDY

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/Match%20(1).csv')
df
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
df=pd.read_csv('https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/Match%20(1).csv')
df.set_index(["Venue_Name","ManOfMach"],inplace=True)
df.head()
a=df.loc["Rajiv Gandhi International Stadium, Uppal"]
a
# Out:
#                    Match_SK  match_id                Team1  \
# ManOfMach
# V Sehwag                  6    335993      Deccan Chargers
# YK Pathan                 8    335995      Deccan Chargers
# SE Marsh                 17    336004      Deccan Chargers
# R Vinay Kumar            20    336007      Deccan Chargers
# SC Ganguly               32    336019      Deccan Chargers
# DJ Bravo                 42    336029      Deccan Chargers
# SK Raina                 54    336042      Deccan Chargers
# SK Trivedi              176    501204      Deccan Chargers
# DW Steyn                185    501213      Deccan Chargers
# PC Valthaty             189    501217      Deccan Chargers
# SL Malinga              200    501229      Deccan Chargers
# YK Pathan               215    501244      Deccan Chargers
# V Sehwag                219    501248      Deccan Chargers
# MR Marsh                226    501255      Deccan Chargers
# DA Warner               271    548334      Deccan Chargers
# ...

# %%
b=a.sort_values('ManOfMach')
b
# Out:
#                    Match_SK  match_id                Team1  \
# ManOfMach
# A Mishra                324    598005  Sunrisers Hyderabad
# A Mishra                389    598070  Sunrisers Hyderabad
# AB Dinda                538    980948  Sunrisers Hyderabad
# AT Rayudu               433    734006  Sunrisers Hyderabad
# B Kumar                 550    980972  Sunrisers Hyderabad
# CH Morris               558    980988  Sunrisers Hyderabad
# DA Warner               504    829804  Sunrisers Hyderabad
# DA Warner               491    829778  Sunrisers Hyderabad
# DA Warner               528    980928  Sunrisers Hyderabad
# DA Warner               543    980958  Sunrisers Hyderabad
# DA Warner               271    548334      Deccan Chargers
# DA Warner               443    734026  Sunrisers Hyderabad
# DJ Bravo                 42    336029      Deccan Chargers
# DJG Sammy               368    598049  Sunrisers Hyderabad
# DW Steyn                185    501213      Deccan Chargers
# ...

# %%
# Print ManOfMach count of each player in Hyderabad stadium

e = b.pivot_table(index=['ManOfMach'],aggfunc='size')
print(e)
# Out:
# ManOfMach
# A Mishra             2
# AB Dinda             1
# AT Rayudu            1
# B Kumar              1
# CH Morris            1
# DA Warner            6
# DJ Bravo             1
# DJG Sammy            1
# DW Steyn             3
# G Gambhir            1
# GH Vihari            2
# I Sharma             1
# MJ McClenaghan       1
# MR Marsh             1
# Mandeep Singh        1
# Mustafizur Rahman    1
# PA Patel             1
# PC Valthaty          1
# R Vinay Kumar        1
# SC Ganguly           1
# SE Marsh             1
# SK Raina             2
# SK Trivedi           1
# SL Malinga           1
# UT Yadav             1
# V Kohli              1
# V Sehwag             2
# WP Saha              1
# YK Pathan            2
# dtype: int64

# %%
def fun(st):
  t= df['Country_Name'].str.contains(st).value_counts()
  p.append(t[1])
p=[]
fun("India")
fun("U.A.E")
fun("South Africa")
p
# Out:
# [560, 20, 57]

# %%
# Plot a pie chart for the country_name column

pd = ["India","U.A.E","South Africa"]
plt.pie(p,labels=pd,startangle=45,explode=[0.1,0,0],colors=["blue","red","green"],autopct="%0.1f%%")
plt.show()
